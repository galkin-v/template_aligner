# %% [markdown]
# ## Align and save to database

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from db_aligner import TemplateAlignerDb

# %%
with TemplateAlignerDb(model_name="gigachat-provider/GigaChat-2") as aligner:
    aligner.run()
# Out:
# 🗄️  Connecting to database at 'templates.db'...
# ✅ Database setup complete.
# ℹ️  Database is empty. Will generate templates for all found products.
# ✨ Generating template for new product: СберДевайсы...
# ❌ Failed to generate template for СберДевайсы. Error: litellm.APIError:
# ✨ Generating template for new product: СберЗдоровье...
# 🗄️  Database connection closed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 with TemplateAlignerDb(model_name="gigachat-provider/GigaChat-2") as aligner:
# ----> 2     aligner.run()
#
# File ~/Documents/VS_Code/work/Sber/template_aligner/db_aligner.py:176, in TemplateAlignerDb.run(self)
#     173     continue
#     175 product_info = product_file.read_text(encoding="utf-8")
# --> 176 generated_content = self._generate_template_for_product(
# ...

# %%
print("\n--- Viewing existing templates ---")
TemplateAlignerDb.view_templates_from_db(TemplateAlignerDb.DB_PATH)

# %% [markdown]
# ## Align and save to folder

# %%
from folder_aligner import TemplateGenerator

# %%
TemplateGenerator()  # gemini-2.5-flash by default
