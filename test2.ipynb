# %%
import litellm
from gigachat_litellm_client import gigachat_handler
import nest_asyncio

nest_asyncio.apply()

litellm.custom_provider_map = [
                {"provider": "gigachat-provider", "custom_handler": gigachat_handler}
            ]

# %%
litellm.completion(model='gigachat-provider/GigaChat-2', messages=[{'role': 'user', 'content': 'hi'}]).content
# Out:
# 'Привет. Как настроение?'
